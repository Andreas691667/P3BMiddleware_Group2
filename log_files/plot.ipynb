# %%
data = read.csv("754341_pl_log.txt", sep=";", header = FALSE)
msg_id = data[1]
timestamp = data[2]
trans_time = data[3]

# %%
boxplot(trans_time, horizontal = TRUE, main = "Transaction time", xlab = "Time (ms)")
# Out:
# Plot with title "Transaction time"
